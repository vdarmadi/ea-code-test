# %%
import pandas as pd

df = pd.read_csv("./bank_enriched_addresses.csv")
df.head()
# Out:
#    age              name                                            address  \
# 0   30  giovanni kessler          17864 Grace Field\nLonzoborough, IN 28057
# 1   33    domenico swift      3887RATKEMEADOWS\NNORTHLEANNATON,VI94092-4948
# 2   35   talon gulgowski    056 pfannerstill cape st.\neast marta, nj 21058
# 3   30       cayla pagac     146 gay fort suite 622\nwest kathryn, la 81781
# 4   59         sim ratke  779 Hegmann Harbors St.\nIsaacmouth, MS 13269-...
#
#            job  marital  education default  balance housing loan   contact  \
# 0   unemployed  married    primary      no     1787      no   no  cellular
# 1     services  married  secondary      no     4789     yes  yes  cellular
# 2   management   single   tertiary      no     1350     yes   no  cellular
# 3   management  married   tertiary      no     1476     yes  yes   unknown
# 4  blue-collar  married  secondary      no        0     yes   no   unknown
#
#    day month  duration  campaign  pdays  previous poutcome   y
# 0   19   oct        79         1     -1         0  unknown  no
# 1   11   may       220         1    339         4  failure  no
# 2   16   apr       185         1    330         1  failure  no
# 3    3   jun       199         4     -1         0  unknown  no
# 4    5   may       226         1     -1         0  unknown  no

# %%
# a. Remove all rows where pdays is -1
df = df.query('pdays != -1')

# %%
# b. Split name into first name and second name columns (drop name)
names = df["name"].str.split(" ", n = 1, expand = True)
df["first_name"] = names[0]
df["second_name"] = names[1]
df.drop(columns = ["name"], inplace = True)
df
# Out:
#       age                                            address            job  \
# 1      33      3887RATKEMEADOWS\NNORTHLEANNATON,VI94092-4948       services
# 2      35    056 pfannerstill cape st.\neast marta, nj 21058     management
# 5      35  3547 Treutel Crossing Apt. 567\nReillytown, AS...     management
# 6      36  177CorneliusCampApt.478\nNikolausbury,AA16457-...  self-employed
# 9      43       03353CORKERYPRAIRIE\NWESTLONNIE,AR87918-1164       services
# ...   ...                                                ...            ...
# 4492   32  7491KILBACKMEADOWAPT.792\NPAGACMOUTH,AS11081-6594     technician
# 4504   42       7081 leffler wall ave.\nkemmerside, dc 00182    blue-collar
# 4514   38  25096 William Fi3ld\nMcCull0ughm0uth, 0R 33380...    blue-collar
# 4519   28  9234 BORER MEADOW AVE.\NPORT LUNABOROUGH, NJ 3...    blue-collar
# 4520   44       2630JenkinsSpringSuite970\nWestLetha,AR93555   entrepreneur
#
#       marital  education default  balance housing loan   contact  day month  \
# 1     married  secondary      no     4789     yes  yes  cellular   11   may
# 2      single   tertiary      no     1350     yes   no  cellular   16   apr
# 5      single   tertiary      no      747      no   no  cellular   23   feb
# 6     married   tertiary      no      307     yes   no  cellular   14   may
# 9     married    primary      no      -88     yes  yes  cellular   17   apr
# ...       ...        ...     ...      ...     ...  ...       ...  ...   ...
# 4492   single  secondary      no      309     yes  yes  cellular   16   apr
# 4504   single  secondary      no     1080     yes  yes  cellular   13   may
# 4514  married  secondary      no     1205     yes   no  cellular   20   apr
# 4519  married  secondary      no     1137      no   no  cellular    6   feb
# 4520   single   tertiary      no     1136     yes  yes  cellular    3   apr
#
#       duration  campaign  pdays  previous poutcome    y first_name second_name
# 1          220         1    339         4  failure   no   domenico       swift
# 2          185         1    330         1  failure   no      talon   gulgowski
# 5          141         2    176         3  failure   no   richmond     effertz
# 6          341         1    330         2    other   no     lauren     mcclure
# 9          313         1    147         2  failure   no    justina      willms
# ...        ...       ...    ...       ...      ...  ...        ...         ...
# 4492       346         1    234         3  failure   no       erna   o'connell
# 4504       951         3    370         4  failure  yes    johnson        beer
# 4514        45         4    153         1  failure   no     maudie  wintheiser
# 4519       129         4    211         3    other   no  zachariah       sipes
# 4520       345         2    249         7    other   no      julio      deckow
#
# [816 rows x 20 columns]

# %%
# Replace the values in the age column with bucketed values, such that
df["age"] = df["age"] // 10
df
# Out:
#       age                                            address            job  \
# 1       3      3887RATKEMEADOWS\NNORTHLEANNATON,VI94092-4948       services
# 2       3    056 pfannerstill cape st.\neast marta, nj 21058     management
# 5       3  3547 Treutel Crossing Apt. 567\nReillytown, AS...     management
# 6       3  177CorneliusCampApt.478\nNikolausbury,AA16457-...  self-employed
# 9       4       03353CORKERYPRAIRIE\NWESTLONNIE,AR87918-1164       services
# ...   ...                                                ...            ...
# 4492    3  7491KILBACKMEADOWAPT.792\NPAGACMOUTH,AS11081-6594     technician
# 4504    4       7081 leffler wall ave.\nkemmerside, dc 00182    blue-collar
# 4514    3  25096 William Fi3ld\nMcCull0ughm0uth, 0R 33380...    blue-collar
# 4519    2  9234 BORER MEADOW AVE.\NPORT LUNABOROUGH, NJ 3...    blue-collar
# 4520    4       2630JenkinsSpringSuite970\nWestLetha,AR93555   entrepreneur
#
#       marital  education default  balance housing loan   contact  day month  \
# 1     married  secondary      no     4789     yes  yes  cellular   11   may
# 2      single   tertiary      no     1350     yes   no  cellular   16   apr
# 5      single   tertiary      no      747      no   no  cellular   23   feb
# 6     married   tertiary      no      307     yes   no  cellular   14   may
# 9     married    primary      no      -88     yes  yes  cellular   17   apr
# ...       ...        ...     ...      ...     ...  ...       ...  ...   ...
# 4492   single  secondary      no      309     yes  yes  cellular   16   apr
# 4504   single  secondary      no     1080     yes  yes  cellular   13   may
# 4514  married  secondary      no     1205     yes   no  cellular   20   apr
# 4519  married  secondary      no     1137      no   no  cellular    6   feb
# 4520   single   tertiary      no     1136     yes  yes  cellular    3   apr
#
#       duration  campaign  pdays  previous poutcome    y first_name second_name
# 1          220         1    339         4  failure   no   domenico       swift
# 2          185         1    330         1  failure   no      talon   gulgowski
# 5          141         2    176         3  failure   no   richmond     effertz
# 6          341         1    330         2    other   no     lauren     mcclure
# 9          313         1    147         2  failure   no    justina      willms
# ...        ...       ...    ...       ...      ...  ...        ...         ...
# 4492       346         1    234         3  failure   no       erna   o'connell
# 4504       951         3    370         4  failure  yes    johnson        beer
# 4514        45         4    153         1  failure   no     maudie  wintheiser
# 4519       129         4    211         3    other   no  zachariah       sipes
# 4520       345         2    249         7    other   no      julio      deckow
#
# [816 rows x 20 columns]

# %%
# d. Replace yes/no values with booleans
df["default"] = df["default"].replace({'yes': True, 'no': False})
df["housing"] = df["housing"].replace({'yes': True, 'no': False})
df["loan"] = df["loan"].replace({'yes': True, 'no': False})
df["y"] = df["y"].replace({'yes': True, 'no': False})
df
# Out:
#       age                                            address            job  \
# 1       3      3887RATKEMEADOWS\NNORTHLEANNATON,VI94092-4948       services
# 2       3    056 pfannerstill cape st.\neast marta, nj 21058     management
# 5       3  3547 Treutel Crossing Apt. 567\nReillytown, AS...     management
# 6       3  177CorneliusCampApt.478\nNikolausbury,AA16457-...  self-employed
# 9       4       03353CORKERYPRAIRIE\NWESTLONNIE,AR87918-1164       services
# ...   ...                                                ...            ...
# 4492    3  7491KILBACKMEADOWAPT.792\NPAGACMOUTH,AS11081-6594     technician
# 4504    4       7081 leffler wall ave.\nkemmerside, dc 00182    blue-collar
# 4514    3  25096 William Fi3ld\nMcCull0ughm0uth, 0R 33380...    blue-collar
# 4519    2  9234 BORER MEADOW AVE.\NPORT LUNABOROUGH, NJ 3...    blue-collar
# 4520    4       2630JenkinsSpringSuite970\nWestLetha,AR93555   entrepreneur
#
#       marital  education  default  balance  housing   loan   contact  day  \
# 1     married  secondary    False     4789     True   True  cellular   11
# 2      single   tertiary    False     1350     True  False  cellular   16
# 5      single   tertiary    False      747    False  False  cellular   23
# 6     married   tertiary    False      307     True  False  cellular   14
# 9     married    primary    False      -88     True   True  cellular   17
# ...       ...        ...      ...      ...      ...    ...       ...  ...
# 4492   single  secondary    False      309     True   True  cellular   16
# 4504   single  secondary    False     1080     True   True  cellular   13
# 4514  married  secondary    False     1205     True  False  cellular   20
# 4519  married  secondary    False     1137    False  False  cellular    6
# 4520   single   tertiary    False     1136     True   True  cellular    3
#
#      month  duration  campaign  pdays  previous poutcome      y first_name  \
# 1      may       220         1    339         4  failure  False   domenico
# 2      apr       185         1    330         1  failure  False      talon
# 5      feb       141         2    176         3  failure  False   richmond
# 6      may       341         1    330         2    other  False     lauren
# 9      apr       313         1    147         2  failure  False    justina
# ...    ...       ...       ...    ...       ...      ...    ...        ...
# 4492   apr       346         1    234         3  failure  False       erna
# 4504   may       951         3    370         4  failure   True    johnson
# 4514   apr        45         4    153         1  failure  False     maudie
# 4519   feb       129         4    211         3    other  False  zachariah
# 4520   apr       345         2    249         7    other  False      julio
#
#      second_name
# 1          swift
# 2      gulgowski
# 5        effertz
# 6        mcclure
# 9         willms
# ...          ...
# 4492   o'connell
# 4504        beer
# 4514  wintheiser
# 4519       sipes
# 4520      deckow
#
# [816 rows x 20 columns]

# %%
# e. Replace day and month with a single date column, of the form dd/MM
month_mapping = {
    "jan": 1, "feb": 2, "mar": 3, "apr": 4, "may": 5, "jun": 6,
    "jul": 7, "aug": 8, "sep": 9, "oct": 10, "nov": 11, "dec": 12
}

# Convert the "month" column to numerical values using the mapping
df["month_numeric"] = df["month"].str.lower().map(month_mapping)

# # Create a new datetime column using "day" and "month_numeric" columns
df["date"] = pd.to_datetime(df['day'].astype(str) + '/' + df['month_numeric'].astype(str), format='%d/%m')

# # Format the "date" column as "dd/MM" and store it in a new column "date"
df["date"] = df["date"].dt.strftime('%d/%m')

df.drop(["month_numeric", "day", "month"], axis=1, inplace=True)

df
# Out:
#       age                                            address            job  \
# 1       3      3887RATKEMEADOWS\NNORTHLEANNATON,VI94092-4948       services
# 2       3    056 pfannerstill cape st.\neast marta, nj 21058     management
# 5       3  3547 Treutel Crossing Apt. 567\nReillytown, AS...     management
# 6       3  177CorneliusCampApt.478\nNikolausbury,AA16457-...  self-employed
# 9       4       03353CORKERYPRAIRIE\NWESTLONNIE,AR87918-1164       services
# ...   ...                                                ...            ...
# 4492    3  7491KILBACKMEADOWAPT.792\NPAGACMOUTH,AS11081-6594     technician
# 4504    4       7081 leffler wall ave.\nkemmerside, dc 00182    blue-collar
# 4514    3  25096 William Fi3ld\nMcCull0ughm0uth, 0R 33380...    blue-collar
# 4519    2  9234 BORER MEADOW AVE.\NPORT LUNABOROUGH, NJ 3...    blue-collar
# 4520    4       2630JenkinsSpringSuite970\nWestLetha,AR93555   entrepreneur
#
#       marital  education  default  balance  housing   loan   contact  \
# 1     married  secondary    False     4789     True   True  cellular
# 2      single   tertiary    False     1350     True  False  cellular
# 5      single   tertiary    False      747    False  False  cellular
# 6     married   tertiary    False      307     True  False  cellular
# 9     married    primary    False      -88     True   True  cellular
# ...       ...        ...      ...      ...      ...    ...       ...
# 4492   single  secondary    False      309     True   True  cellular
# 4504   single  secondary    False     1080     True   True  cellular
# 4514  married  secondary    False     1205     True  False  cellular
# 4519  married  secondary    False     1137    False  False  cellular
# 4520   single   tertiary    False     1136     True   True  cellular
#
#       duration  campaign  pdays  previous poutcome      y first_name  \
# 1          220         1    339         4  failure  False   domenico
# 2          185         1    330         1  failure  False      talon
# 5          141         2    176         3  failure  False   richmond
# 6          341         1    330         2    other  False     lauren
# 9          313         1    147         2  failure  False    justina
# ...        ...       ...    ...       ...      ...    ...        ...
# 4492       346         1    234         3  failure  False       erna
# 4504       951         3    370         4  failure   True    johnson
# 4514        45         4    153         1  failure  False     maudie
# 4519       129         4    211         3    other  False  zachariah
# 4520       345         2    249         7    other  False      julio
#
#      second_name   date
# 1          swift  11/05
# 2      gulgowski  16/04
# 5        effertz  23/02
# 6        mcclure  14/05
# 9         willms  17/04
# ...          ...    ...
# 4492   o'connell  16/04
# 4504        beer  13/05
# 4514  wintheiser  20/04
# 4519       sipes  06/02
# 4520      deckow  03/04
#
# [816 rows x 19 columns]

# %%
# f. Rename the y column to “outcome"
df = df.rename(columns = {"y":"outcome"})
df
# Out:
#       age                                            address            job  \
# 1       3      3887RATKEMEADOWS\NNORTHLEANNATON,VI94092-4948       services
# 2       3    056 pfannerstill cape st.\neast marta, nj 21058     management
# 5       3  3547 Treutel Crossing Apt. 567\nReillytown, AS...     management
# 6       3  177CorneliusCampApt.478\nNikolausbury,AA16457-...  self-employed
# 9       4       03353CORKERYPRAIRIE\NWESTLONNIE,AR87918-1164       services
# ...   ...                                                ...            ...
# 4492    3  7491KILBACKMEADOWAPT.792\NPAGACMOUTH,AS11081-6594     technician
# 4504    4       7081 leffler wall ave.\nkemmerside, dc 00182    blue-collar
# 4514    3  25096 William Fi3ld\nMcCull0ughm0uth, 0R 33380...    blue-collar
# 4519    2  9234 BORER MEADOW AVE.\NPORT LUNABOROUGH, NJ 3...    blue-collar
# 4520    4       2630JenkinsSpringSuite970\nWestLetha,AR93555   entrepreneur
#
#       marital  education  default  balance  housing   loan   contact  \
# 1     married  secondary    False     4789     True   True  cellular
# 2      single   tertiary    False     1350     True  False  cellular
# 5      single   tertiary    False      747    False  False  cellular
# 6     married   tertiary    False      307     True  False  cellular
# 9     married    primary    False      -88     True   True  cellular
# ...       ...        ...      ...      ...      ...    ...       ...
# 4492   single  secondary    False      309     True   True  cellular
# 4504   single  secondary    False     1080     True   True  cellular
# 4514  married  secondary    False     1205     True  False  cellular
# 4519  married  secondary    False     1137    False  False  cellular
# 4520   single   tertiary    False     1136     True   True  cellular
#
#       duration  campaign  pdays  previous poutcome  outcome first_name  \
# 1          220         1    339         4  failure    False   domenico
# 2          185         1    330         1  failure    False      talon
# 5          141         2    176         3  failure    False   richmond
# 6          341         1    330         2    other    False     lauren
# 9          313         1    147         2  failure    False    justina
# ...        ...       ...    ...       ...      ...      ...        ...
# 4492       346         1    234         3  failure    False       erna
# 4504       951         3    370         4  failure     True    johnson
# 4514        45         4    153         1  failure    False     maudie
# 4519       129         4    211         3    other    False  zachariah
# 4520       345         2    249         7    other    False      julio
#
#      second_name   date
# 1          swift  11/05
# 2      gulgowski  16/04
# 5        effertz  23/02
# 6        mcclure  14/05
# 9         willms  17/04
# ...          ...    ...
# 4492   o'connell  16/04
# 4504        beer  13/05
# 4514  wintheiser  20/04
# 4519       sipes  06/02
# 4520      deckow  03/04
#
# [816 rows x 19 columns]

# %%
# Add a column which categorizes geographical features in the address, where present. Note the dirtiness of the address data and that the exact categories:
# a. “water”, where the address contains e.g. lake, creek
# b. “relief”, where the address contains e.g. hill, canyon
# c. “flat”, where the address contains e.g. plain
def categorize_geographical_feature(address):
    address = address.lower()
    if any(keyword in address for keyword in ["lake", "creek", "river"]):
        return "water"
    elif any(keyword in address for keyword in ["hill", "canyon"]):
        return "relief"
    elif any(keyword in address for keyword in ["plain"]):
        return "flat"
    else:
        return "unknown"

df["geographical_feature"] = df["address"].apply(categorize_geographical_feature)

# %%
# Group by the feature (if you created it, or by some other field if not) 
# and filter out any empty values, sort by the age bucket (or age if you didn’t 
# do the bucketing), and return a row count.
agg_df = df.dropna()
agg_df = agg_df.query('geographical_feature != "unknown"')
agg_df = agg_df.groupby(["geographical_feature", "age"]).size().reset_index(name='counts').sort_values("age")

# %%
# Write the row level data from step 2, and aggregated data from step 3 to both CSV and parquet formats.
df.to_csv('step_2.csv', index=False)
df.to_parquet('step_2.parquet.gzip', compression='gzip', index=False)
pd.read_parquet('step_2.parquet.gzip')  

agg_df.to_csv('step_4.csv', index=False)
agg_df.to_parquet('step_4.parquet.gzip', compression='gzip', index=False)
pd.read_parquet('step_4.parquet.gzip')
# Out:
#    geographical_feature  age  counts
# 0                  flat    2       1
# 1                relief    2       2
# 2                 water    2       6
# 3                  flat    3       4
# 4                relief    3       5
# 5                 water    3      21
# 6                  flat    4       3
# 7                relief    4       2
# 8                 water    4      11
# 9                  flat    5       1
# 10               relief    5       5
# 11                water    5       2
# 12                 flat    7       1
# 13               relief    7       2
# 14                water    7       1
